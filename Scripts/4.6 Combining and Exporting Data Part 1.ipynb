# %% [markdown]
# # Table of Contents
# 1. Import libaries
# 2. Import data: orders_products_prior.csv, orders_checked.csv
# 3. Data cleaning on orders_products_prior.csv: missing values, duplicates checks
# 4. Merging datasets: orders_checked.csv and orders_products_prior.csv
# 5. Export merged dataset as pkl: orders_products_combined.pkl

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Data

# %%
# Define path
path = r'/users/stephenhelvig/documents/python projects/instacart basket analysis'

# %%
# Import orders_products_prior.csv
df_ords_prior = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'orders_products_prior.csv'), index_col = False)

# %%
# Import orders_checked.csv
df_ords = pd.read_csv(os.path.join(path, 'Data', 'Prepared Data', 'orders_checked.csv'), index_col = False)

# %% [markdown]
# # Data Cleaning: orders_products_prior.csv

# %%
# Check the output
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  first_order
# 0                     NaN         True
# 1                    15.0        False
# 2                    21.0        False
# 3                    29.0        False
# 4                    28.0        False

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
# checking for missing values

df_ords_prior.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
# checking for duplicates
df_dups = df_ords_prior[df_ords_prior.duplicated()]

print(df_dups)
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %% [markdown]
# # Merging Datasets: orders_checked.csv and orders_products_prior.csv

# %%
# Merging df_ords with dr_ords_prior
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
# Checking the output
df_merged_large.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# # Exporting Data

# %%
# Export data to pkl
df_merged_large.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_combined.pkl'))
