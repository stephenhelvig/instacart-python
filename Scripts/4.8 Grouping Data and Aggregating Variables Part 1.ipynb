# %% [markdown]
# # Table of Contents
# 1. Import libraries
# 2. Import data: ords_prods_merge_extrarows.pkl
# 3. Create new 'max_order' value using .transform(max) aggregation
# 4. Create a new 'loyalty_flag' value based on 'max_order' value using loc()
# 5. Export data: ords_prods_merge2_extrarows.pkl

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Data

# %%
# define path

path = r'/users/stephenhelvig/documents/python projects/instacart basket analysis'

# %%
# import ords_prods_merge

ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'ords_prods_merge_extrarows.pkl'))

# %% [markdown]
# # Create new 'max_order' value using .transform(max) aggregation

# %%
# Aggregating data with transform()

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform('max')

# %%
ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2539329        1             1                  2                  8
# 2    2539329        1             1                  2                  8
# 3    2539329        1             1                  2                  8
# 4    2539329        1             1                  2                  8
# 5    2398795        1             2                  3                  7
# 6    2398795        1             2                  3                  7
# 7    2398795        1             2                  3                  7
# 8    2398795        1             2                  3                  7
# 9    2398795        1             2                  3                  7
# 10   2398795        1             2                  3                  7
# 11    473747        1             3                  3                 12
# ...

# %%
pd.options.display.max_rows = None

# %% [markdown]
# # Create a new 'loyalty_flag' based on 'max_order' value using loc()

# %%
# assigning a loyalty flag based on the max_order value

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15891172
# Loyal customer      10293959
# New customer         6249358
# Name: count, dtype: int64

# %%
# checking the results
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(80)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# ..      ...               ...           ...
# 75        2  Regular customer             2
# 76        2  Regular customer             2
# 77        2  Regular customer             2
# 78        2  Regular customer             3
# 79        2  Regular customer             3
#
# [80 rows x 3 columns]

# %% [markdown]
# # Export Data

# %%
ords_prods_merge.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'ords_prods_merge2_extrarows.pkl'))
